# %%
import os
from datetime import datetime

nowdate = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")
years = ["2015"]
variable = [
        "2m_temperature",
        "total_precipitation",
        # additional (2026.02.18)
        "2m_dewpoint_temperature",
        # "soil_temperature_level_1",
        # "volumetric_soil_water_layer_1",
        # "high_vegetation_cover",
        # "low_vegetation_cover",
        # "total_cloud_cover"
    ]
temp_filename = os.path.join(f"{nowdate}_{years[0]}_{"-".join([var for var in variable])}.grib")
temp_filename
# Out:
# '20260218_133814_2015_2m_temperature-total_precipitation-2m_dewpoint_temperature.grib'

# %%
times = [f"{number:02d}:00" for number in range(24)]
max(times)
# Out:
# '23:00'

# %%
years = ["2015"]
months = [f"{number:02d}" for number in range(1, 12+1)]
days = [f"{number:02d}" for number in range(1, 31+1)]
times = [f"{number:02d}:00" for number in range(24)]
variable = [
        "2m_temperature",
        "total_precipitation",
        # additional (2026.02.18)
        "2m_dewpoint_temperature",
        # "soil_temperature_level_1",
        # "volumetric_soil_water_layer_1",
        # "high_vegetation_cover",
        # "low_vegetation_cover",
        # "total_cloud_cover"
    ]


print("=========================================================")
print("Downloading {year}-{min_month}-{min_day} to {year}-{max_month}-{max_day} ".format(
    year=years[0], 
    min_month=min(months), max_month=max(months),
    min_day=min(days), max_day=max(days),
))
print("Variables: {var}".format(var=variable))
# Out:
# =========================================================
# Downloading 2015-01-01 to 2015-12-31
# Variables: ['2m_temperature', 'total_precipitation', '2m_dewpoint_temperature']

# %%
 [year for year in range(2016, 2025)]
# Out:
# [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
